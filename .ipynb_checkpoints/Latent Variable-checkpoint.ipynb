# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_regression, SelectKBest, chi2
import statsmodels.api as sm
import numpy as np
from statsmodels.formula.api import ols
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

# %%
data = pd.read_csv (r'data_clean_4_21.csv')
# remove those without fips_code
data.dropna(subset = ["fips_code"], inplace=True)
data.dropna(subset = ["ICU.Bed.Occupancy.Rate"], inplace=True)
data.dropna(subset = ["population_20"], inplace=True)
#data.isnull().sum()
X = data.drop(['fips_code', 'date', 'county', 'State', 'Staffed.All.Beds', 'Staffed.ICU.Beds', 'Licensed.All.Beds',
       'All.Bed.Occupancy.Rate', 'ICU.Bed.Occupancy.Rate', 'Population', 'Population_2010',
       'Population..20..', 'Population..65..',
       'Staffed.All.Beds..Per.1000.People.',
       'Staffed.All.Beds..Per.1000.Adults..20...',
       'Staffed.All.Beds..Per.1000.Elderly..65...',
       'Staffed.ICU.Beds..Per.1000.People.',
       'Staffed.ICU.Beds..Per.1000.Adults..20...',
       'Staffed.ICU.Beds..Per.1000.Elderly..65...',
       'Licensed.All.Beds..Per.1000.People.',
       'Licensed.All.Beds..Per.1000.Adults..20...',
       'Licensed.All.Beds..Per.1000.Elderly..65...', 'county_x', 'County_Name', 'Area_name'], axis = 1)
X['state'] = X.state.factorize()[0]
X['Description'] = X.Description.factorize()[0]
X['peopleinpoverty2018'] = X.peopleinpoverty2018.factorize()[0]
X['medianhouseholdincome'] = X.medianhouseholdincome.factorize()[0]
Y_c = data['cases']
Y_d = data['deaths']
X_new = X.drop(['population'], axis = 1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_new, Y_d, test_size = 0.7, random_state = 1)

# %% [markdown]
# ## Gaussian Process Latent Variable Model

# %%
import seaborn as sns
import os
import matplotlib.pyplot as plt
import pandas as pd
import torch
from torch.nn import Parameter

import pyro
import pyro.contrib.gp as gp
import pyro.distributions as dist
import pyro.ops.stats as stats
#assert pyro.__version__.startswith('1.3.0')
pyro.enable_validation(True)       # can help with debugging
pyro.set_rng_seed(1)

# %%
data = torch.tensor(X_new.values, dtype=torch.get_default_dtype())

# %%
X_new
# Out:
#       state  cases  deaths  staffed_all_beds  staffed_icu_beds  \
# 0         0     30       1              55.0               6.0
# 1         0    123       3             362.0              51.0
# 2         0     28       0              30.0               5.0
# 4         0     26       0              25.0               6.0
# 6         0     15       0              66.0               7.0
# ...     ...    ...     ...               ...               ...
# 2747     50     38       0             372.0              14.0
# 2750     50     12       0              71.0              11.0
# 2752     50     10       0              74.0              10.0
# 2753     50     62       0              48.0               6.0
# 2754     50      6       0             105.0               6.0
#
#       licensed_all_beds  all_bed_occupancy_rate  icu_bed_occupancy_rate  \
# 0                  85.0                    0.62                    0.53
# 1                 386.0                    0.64                    0.65
# 2                  74.0                    0.43                    0.42
# 4                  25.0                    0.50                    0.34
# 6                  94.0                    0.18                    0.38
# ...                 ...                     ...                     ...
# 2747              414.0                    0.55                    0.56
# 2750               88.0                    0.37                    0.34
# 2752              115.0                    0.25                    0.23
# 2753               48.0                    0.36                    0.33
# 2754              225.0                    0.58                    0.11
#
#       population_20  population_65  ...  \
# 0           41177.0         8653.0  ...
# 1          166352.0        44571.0  ...
# 2           19189.0         4832.0  ...
# 4           43175.0        10548.0  ...
# 6           14868.0         3995.0  ...
# ...             ...            ...  ...
# 2747        58314.0        12180.0  ...
# 2750        23021.0         6347.0  ...
# 2752        30621.0         5214.0  ...
# 2753        18512.0         3558.0  ...
# 2754        13973.0         2858.0  ...
#
#       staffed_icu_beds_.per_1000_elderly_65..  \
# 0                                       0.693
# 1                                       1.144
# 2                                       1.035
# 4                                       0.569
# 6                                       1.752
# ...                                       ...
# 2747                                    1.149
# 2750                                    1.733
# 2752                                    1.918
# 2753                                    1.686
# 2754                                    2.099
#
#       licensed_all_beds_per_1000_people  \
# 0                                 1.529
# 1                                 1.770
# 2                                 2.974
# 4                                 0.432
# 6                                 4.776
# ...                                 ...
# 2747                              5.233
# 2750                              2.911
# 2752                              2.671
# 2753                              2.080
# 2754                             11.084
#
#       licensed_all_beds_.per_1000_adults_20..  \
# 0                                       2.064
# 1                                       2.320
# 2                                       3.856
# 4                                       0.579
# 6                                       6.322
# ...                                       ...
# 2747                                    7.099
# 2750                                    3.823
# 2752                                    3.756
# 2753                                    2.593
# 2754                                   16.102
#
#       licensed_all_beds_.per_1000_elderly_65..  RUCC_2013  Description  \
# 0                                        9.823        2.0            0
# 1                                        8.660        3.0            1
# 2                                       15.315        6.0            2
# 4                                        2.370        1.0            3
# 6                                       23.529        6.0            2
# ...                                        ...        ...          ...
# 2747                                    33.990        3.0            1
# 2750                                    13.865        7.0            6
# 2752                                    22.056        5.0            7
# 2753                                    13.491        7.0            6
# 2754                                    78.726        7.0            6
#
#       Rural.urban_Continuum_Code_2013  Urban_Influence_Code_2013  \
# 0                                 2.0                        2.0
# 1                                 3.0                        2.0
# 2                                 6.0                        6.0
# 4                                 1.0                        1.0
# 6                                 6.0                        6.0
# ...                               ...                        ...
# 2747                              3.0                        2.0
# 2750                              7.0                        8.0
# 2752                              5.0                        8.0
# 2753                              7.0                        8.0
# 2754                              7.0                        8.0
#
#       peopleinpoverty2018  medianhouseholdincome
# 0                       0                      0
# 1                       1                      1
# 2                       2                      2
# 4                       3                      3
# 6                       4                      4
# ...                   ...                    ...
# 2747                 1320                   1341
# 2750                 1321                   1342
# 2752                 1322                   1343
# 2753                 1323                   1344
# 2754                 1324                   1345
#
# [1364 rows x 25 columns]

# %%
X_gp = np.array(X_new).T
# Out:
# array([[0.000e+00, 0.000e+00, 0.000e+00, ..., 5.000e+01, 5.000e+01,
#         5.000e+01],
#        [3.000e+01, 1.230e+02, 2.800e+01, ..., 1.000e+01, 6.200e+01,
#         6.000e+00],
#        [1.000e+00, 3.000e+00, 0.000e+00, ..., 0.000e+00, 0.000e+00,
#         0.000e+00],
#        ...,
#        [2.000e+00, 2.000e+00, 6.000e+00, ..., 8.000e+00, 8.000e+00,
#         8.000e+00],
#        [0.000e+00, 1.000e+00, 2.000e+00, ..., 1.322e+03, 1.323e+03,
#         1.324e+03],
#        [0.000e+00, 1.000e+00, 2.000e+00, ..., 1.343e+03, 1.344e+03,
#         1.345e+03]])

# %%
train_set = np.random.choice([True, False], len(Y_d), p = [0.75, 0.25])

# %%
from sklearn.gaussian_process import GaussianProcessRegressor as GP

# %%
X[train_set]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-ca2e146eaf9c> in <module>
# ----> 1 X[train_set]
#
# /opt/anaconda3/envs/Computational_methods/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984         # Do we have a (boolean) 1d indexer?
#    2985         if com.is_bool_indexer(key):
# -> 2986             return self._getitem_bool_array(key)
#    2987
#    2988         # We are left with two options: a single key, and a collection of keys,
#
# /opt/anaconda3/envs/Computational_methods/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3031         elif len(key) != len(self.index):
#    3032             raise ValueError(
# -> 3033                 "Item wrong length %d instead of %d." % (len(key), len(self.index))
#    3034             )
#    3035
#
# ValueError: Item wrong length 955 instead of 1364.

# %%
Y_d[train_set]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-e062ea299b2c> in <module>
# ----> 1 Y_d[train_set]
#
# /opt/anaconda3/envs/Computational_methods/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1109
#    1110         if com.is_bool_indexer(key):
# -> 1111             key = check_bool_indexer(self.index, key)
#    1112
#    1113         return self._get_with(key)
#
# /opt/anaconda3/envs/Computational_methods/lib/python3.6/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2422         if len(result) != len(index):
#    2423             raise IndexError(
# -> 2424                 "Item wrong length {} instead of {}.".format(len(result), len(index))
#    2425             )
#    2426
#
# IndexError: Item wrong length 955 instead of 1364.

# %%
gp = GP()
gp.fit(X_new[train_set], Y_d[train_set])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-d817ccad64e1> in <module>
#       1 gp = GP()
# ----> 2 gp.fit(X_new[train_set], Y_d[train_set])
#
# /opt/anaconda3/envs/Computational_methods/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984         # Do we have a (boolean) 1d indexer?
#    2985         if com.is_bool_indexer(key):
# -> 2986             return self._getitem_bool_array(key)
#    2987
#    2988         # We are left with two options: a single key, and a collection of keys,
#
# /opt/anaconda3/envs/Computational_methods/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3031         elif len(key) != len(self.index):
#    3032             raise ValueError(
# -> 3033                 "Item wrong length %d instead of %d." % (len(key), len(self.index))
#    3034             )
#    3035
#
# ValueError: Item wrong length 955 instead of 1364.

# %%
epsilon = np.random.normal(loc=0, scale=0.4a, size=n)

# %%
fig, ax = plt.subplots()

# Plot function f. 
sns.lineplot(x=X_gp, y=f_x, color='red', label = 'f(x)', ax=ax)
